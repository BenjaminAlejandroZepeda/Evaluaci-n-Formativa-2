# %% [markdown]
# # Formulario Python Resumen EA1

# %% [markdown]
# ## Importar bibliotecas o librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ## Definición de una función

# %%
def f(x):
    return #expresión de la función

# %% [markdown]
# ## Graficar una función

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return # función a graficar

x = np.arange(valor inicial, valor final, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Nombre del gráfico')
plt.xlabel('Nombre eje x')
plt.ylabel('Nombre eje y')
plt.legend()
plt.show()

# %% [markdown]
# ## Encontrar forma algebraica de una función lineal

# %%
import numpy as np
x = np.array([valor 1, valor 2, valor 3, …, valor n])
y = np.array([valor 1, valor 2, valor 3, …, valor n])
#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)
print(f'La pendiente es {pendiente} y el intercepto es {intercepto}')

# %% [markdown]
# ## Encontrar preimagen dado el valor de una función

# %%
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return #'función igualada a cero'

#Valor/es inicial/es de la aproximación
x = np.linspace(valor inicial, valor final, cantidad de valores del arreglo)
solucion = fsolve(f, x)
print(f'El valor de x es {solucion[0]}')

# %% [markdown]
# ## Determinar los puntos de intersección de dos funciones

# %%
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return #expresión de f(x)

def g(x):
    return #expresión de g(x)

#definir una nueva función f(x)-g(x)

def inter(x):
    return f(x)-g(x)
x=np.linspace(valor incial,valor final,cantidad de valores)
solucion=np.around(fsolve(inter,x),decimals=2)

interseccion=np.unique(solucion)

print(f'Los puntos de intersección se tienen cuando x={interseccion}')
